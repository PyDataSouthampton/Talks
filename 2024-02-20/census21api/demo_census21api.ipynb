# %%
import urllib3
urllib3.disable_warnings() # disable InsecureRequestWarning if using verify=False

# %% [markdown]
# # Demo of the census21api module

# %% [markdown]
# In order to use the census21api tool you will first have to
#
# ```bash
# $ python -m pip install census21api@git+https://github.com/datasciencecampus/census21api
# ```
#
# alternative methods of instaliation can be found in the [repo](https://github.com/datasciencecampus/census21api). After instilation, if you also want to make the interactive map at the bottom I would recomend creating a new conda enviroemnt and installing the census21api tool as well as the ```requirements.txt```.
#
# You can then import the core class from the module. Then create an instance of the class.

# %%
from census21api import CensusAPI

api = CensusAPI()

# %% [markdown]
# ## Querying population, area and feature types

# %% [markdown]
# After creating an instance you will need three key ingridients to feed into a query: population type, area type and feature(s). A population type must always be chosen first. The tool can help you choose what ingriedients to put into a query. In the cell below we fetch information on all of the population types avaliable to us.
#
# This creates a query and sends it to the Create A Custom Dataset API, this pulls down all of the metadata as a JSON and renders it.

# %%
populations = api.query_population_types()
populations
# Out:
#     name                                           label  \
# 0     HH                                  All households
# 1    HRP                 All Household Reference Persons
# 2     UR                             All usual residents
# 3  UR_CE  All usual residents in communal establishments
# 4  UR_HH               All usual residents in households
#
#                                          description       type
# 0  Either one usual resident living alone or a gr...  microdata
# 1  A person who serves as a reference point, main...  microdata
# 2  The main population base for census statistics...  microdata
# 3  A usual resident who lives in a place that pro...  microdata
# 4  A person who usually lives in England or Wales...  microdata

# %% [markdown]
# For this demonstraition we are going to choose to look at household reference persons.

# %%
population_type = "HRP"

# %% [markdown]
# Next we can look at the different are types avaliable to us. Below I query all area types avaliable for the given population type of household reference persons.

# %%
area_types = api.query_feature(population_type, "area-types")
area_types
# Out:
#         id                                              label  \
# 0      nat                                  England and Wales
# 1     ctry                                          Countries
# 2      rgn                                            Regions
# 3      lep                      Local enterprise partnerships
# 4    nhser                                NHS England regions
# 5      lhb                                Local health boards
# 6      icb                             Integrated care boards
# 7    sicbl                Sub integrated care board locations
# 8   utla23                  2023 Upper tier local authorities
# 9     utla                       Upper tier local authorities
# 10  ltla23                  2023 Lower tier local authorities
# 11    ltla                       Lower tier local authorities
# 12    senc                              Senedd constituencies
# 13  p19wpc  Post-2019 Westminster Parliamentary constituen...
# 14   sener                           Senedd electoral regions
# 15     wpc           Westminster Parliamentary constituencies
# 16      wd                      Electoral wards and divisions
# 17    msoa                    Middle layer Super Output Areas
# 18    lsoa                     Lower layer Super Output Areas
# 19      oa                                       Output Areas
#
#                                           description  total_count  \
# 0                    Data for both England and Wales.            1
# 1      Data for either the whole of England or Wales.            2
# 2   Data for the nine regions in England, and Wale...           10
# 3   Local enterprise partnerships (LEPs) are volun...           37
# 4   Each NHS region is responsible for planning lo...            8
# 5   Local health boards in Wales are responsible f...            8
# 6   Integrated care boards in England are responsi...           43
# 7   Sub integrated care board locations have repla...          107
# 8   Upper tier local authorities provide a range o...          175
# 9   Upper tier local authorities provide a range o...          174
# 10  Lower tier local authorities provide a range o...          318
# 11  Lower tier local authorities provide a range o...          331
# 12  Areas used to elect a member of the Senedd (MS...           41
# 13  Areas that will be used to elect members of pa...          575
# 14  There are five Senedd electoral regions each m...            6
# 15  Areas used to elect a member of parliament (MP...          573
# 16  Areas used to elect local authority councillor...         7638
# 17  Middle layer Super Output Areas (MSOAs) are ma...         7264
# 18  Lower layer Super Output Areas (LSOAs) are mad...        35672
# 19  The lowest level of geographical area for cens...       188880
#
#     hierarchy_order population_type
# 0              1400             HRP
# 1              1300             HRP
# 2              1200             HRP
# 3              1150             HRP
# 4              1100             HRP
# 5              1000             HRP
# 6               900             HRP
# 7               800             HRP
# 8               750             HRP
# 9               700             HRP
# 10              650             HRP
# 11              600             HRP
# 12              550             HRP
# 13              525             HRP
# 14              520             HRP
# 15              500             HRP
# 16              400             HRP
# 17              300             HRP
# 18              200             HRP
# 19              100             HRP

# %% [markdown]
# The final ingrideint is the feature(s). We can choose one or more features for a query. The more features we have the more likely we are to get some missing values because the statistical disclosure control means we cant see very small counts. Instead of querying all possible features avaliable I restrict the search for those begining with ```hh_deprevation``` the ```hh_``` means only features which are relavant to hosueholds. We restrict to features that are measures of deprevation here just because there are so many possibilities.

# %%
dimensions = api.query_feature(population_type, "dimensions")
dimensions[dimensions['id'].str.startswith("hh_deprivation")]
# Out:
#                            id  \
# 20             hh_deprivation
# 21   hh_deprivation_education
# 22  hh_deprivation_employment
# 23      hh_deprivation_health
# 24     hh_deprivation_housing
#
#                                                 label  \
# 20               Household deprivation (6 categories)
# 21  Household deprived in the education dimension ...
# 22  Household deprived in the employment dimension...
# 23  Household deprived in the health and disabilit...
# 24  Household deprived in the housing dimension (3...
#
#                                           description  total_count  \
# 20  The dimensions of deprivation used to classify...            6
# 21  A household is classified as deprived in the e...            3
# 22  A household is classified as deprived in the e...            3
# 23  A household is classified as deprived in the h...            3
# 24  A household is classified as deprived in the h...            3
#
#                                quality_statement_text population_type
# 20  Caution should be used in interpreting this va...             HRP
# 21                                                                HRP
# 22                                                                HRP
# 23                                                                HRP
# 24                                                                HRP

# %% [markdown]
# Now we can choose the area type and feature that we will feed to the query. In this example we choose local authorities as defined with 2023 boundaries. We also choose to looko at the feature households deprived in the housing dimension.

# %%
area_type = "ltla23"
dimension = "hh_deprivation_housing"

# %% [markdown]
# We feed these into a query, as we only have one dimension we wrap it in a list to make it an itterable with a single element. The ooutput shows us how many household reference people live in non-deprived (0) and deprived (1) housing. It also counts the number of people for whom we are missing the data or for whom the measure doesnt apply (-8).

# %%
table = api.query_table(population_type, area_type, [dimension])
table.head(6)
# Out:
#       ltla23  hh_deprivation_housing  count population_type
# 0  E06000001                      -8      0             HRP
# 1  E06000001                       0  39304             HRP
# 2  E06000001                       1   1626             HRP
# 3  E06000002                      -8      0             HRP
# 4  E06000002                       0  56978             HRP
# 5  E06000002                       1   3284             HRP

# %% [markdown]
# ## Creating an interactive map

# %% [markdown]
# After we have the data we can visualise it. We do that here with an interactive map.

# %%
import geopandas as gpd
import pandas as pd
import pyproj
import matplotlib.pyplot as plt

# %% [markdown]
# The shape files and lookup tables we need can be found on the [ONS Open Geography Portal](https://geoportal.statistics.gov.uk/)
#
# The shape files can be found [here](https://geoportal.statistics.gov.uk/datasets/608940e46ed649e3b00a5409befe31f8_0/explore).
# The lookup table can be found [here](https://geoportal.statistics.gov.uk/datasets/ons::middle-layer-super-output-area-2021-to-ward-to-lad-may-2023-lookup-in-england-and-wales/about).

# %%
bounds = gpd.read_file('data/MSOA_2021_EW_BFC_V6.shp')
bounds.head()
# Out:
#     MSOA21CD                  MSOA21NM   BNG_E   BNG_N      LONG      LAT  \
# 0  E02000001        City of London 001  532384  181355 -0.093490  51.5156
# 1  E02000002  Barking and Dagenham 001  548267  189685  0.138756  51.5865
# 2  E02000003  Barking and Dagenham 002  548259  188520  0.138149  51.5760
# 3  E02000004  Barking and Dagenham 003  551004  186412  0.176828  51.5564
# 4  E02000005  Barking and Dagenham 004  548733  186824  0.144267  51.5607
#
#                                GlobalID  \
# 0  283e7adc-faef-4736-9a0b-146cb27c72ec
# 1  7b32290e-3b18-45b1-b5d5-bf778f71e3ce
# 2  56f43674-2eda-47c0-819a-0cabeb9595f5
# 3  fbedb5c5-b92a-475f-899e-1baf1dbae111
# 4  f04829fe-a903-4bca-a88a-ace39fdbd3ac
#
#                                             geometry
# 0  POLYGON ((532153.703 182165.155, 532158.250 18...
# 1  POLYGON ((548881.304 190819.980, 548881.125 19...
# 2  POLYGON ((548958.555 189072.176, 548954.517 18...
# 3  POLYGON ((551550.056 187364.705, 551528.633 18...
# 4  POLYGON ((549237.051 187627.941, 549241.319 18...

# %%
lookup = pd.read_csv("data/MSOA_2021_to_LAD_2023_Lookup.csv")
lookup.head()
# Out:
#     MSOA21CD        MSOA21NM MSOA21NMW     WD23CD              WD23NM WD23NMW  \
# 0  E02002489  Hartlepool 007       NaN  E05013038         Burn Valley     NaN
# 1  E02002490  Hartlepool 008       NaN  E05013041         Foggy Furze     NaN
# 2  E02002483  Hartlepool 001       NaN  E05013042                Hart     NaN
# 3  E02002484  Hartlepool 002       NaN  E05013043  Headland & Harbour     NaN
# 4  E02002491  Hartlepool 009       NaN  E05013044         Manor House     NaN
#
#      LAD23CD     LAD23NM LAD23NMW  ObjectId
# 0  E06000001  Hartlepool      NaN         1
# 1  E06000001  Hartlepool      NaN         2
# 2  E06000001  Hartlepool      NaN         3
# 3  E06000001  Hartlepool      NaN         4
# 4  E06000001  Hartlepool      NaN         5

# %% [markdown]
# We combine the local authority codes and names with their boundary data.

# %%
auths = bounds.merge(lookup).dissolve(by=["LAD23CD", "LAD23NM"])[["geometry"]].reset_index()
auths["geometry"] = auths["geometry"].simplify(100).buffer(0)
auths.head()
# Out:
#      LAD23CD               LAD23NM  \
# 0  E06000001            Hartlepool
# 1  E06000002         Middlesbrough
# 2  E06000003  Redcar and Cleveland
# 3  E06000004      Stockton-on-Tees
# 4  E06000005            Darlington
#
#                                             geometry
# 0  POLYGON ((452352.503 530704.054, 452701.750 52...
# 1  MULTIPOLYGON (((451933.804 516881.716, 453270....
# 2  MULTIPOLYGON (((468700.724 522049.101, 469891....
# 3  MULTIPOLYGON (((446745.187 513828.305, 447079....
# 4  POLYGON ((435827.188 515305.187, 436038.000 51...

# %% [markdown]
# We combine the above with the calculation proportion of household refernce people in each local authority who live in deprived housing.

# %%
feature = f"prop_{dimension}"
table[feature] = table["count"]/ table.groupby("ltla23")["count"].transform("sum")

deprived = table[table[dimension]>0][["ltla23", feature]]

combined = auths.merge(deprived, left_on="LAD23CD", right_on= "ltla23")

# %% [markdown]
# We create an interactive map. We can see hotspots of local authorities with higher proportions  of deprived housing in some cities such as London and in rural areas such as Cornwall.

# %%
combined.explore(feature, cmap = "magma")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7e5caad7b1b5b59555da365f84129ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7e5caad7b1b5b59555da365f84129ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7e5caad7b1b5b59555da365f84129ea = L.map(
#                 &quot;map_d7e5caad7b1b5b59555da365f84129ea&quot;,
#                 {
#                     center: [52.837944696798615, -2.327460546851892],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d7e5caad7b1b5b59555da365f84129ea);
#
#
#
#
#
#             var tile_layer_323a2d12cb95f55d8a40719e2fb17e9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_323a2d12cb95f55d8a40719e2fb17e9e.addTo(map_d7e5caad7b1b5b59555da365f84129ea);
#
#
#             map_d7e5caad7b1b5b59555da365f84129ea.fitBounds(
#                 [[49.86479803644233, -6.418601200411691], [55.81109135715489, 1.7636801067079062]],
#                 {}
#             );
#
#
#         function geo_json_68036067f900b9c2420620a21aca528b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;38&quot;: case &quot;50&quot;: case &quot;88&quot;: case &quot;103&quot;: case &quot;105&quot;: case &quot;173&quot;: case &quot;184&quot;: case &quot;203&quot;: case &quot;225&quot;: case &quot;241&quot;: case &quot;300&quot;: case &quot;316&quot;:
#                     return {&quot;color&quot;: &quot;#0c0926&quot;, &quot;fillColor&quot;: &quot;#0c0926&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;83&quot;: case &quot;204&quot;:
#                     return {&quot;color&quot;: &quot;#1e1149&quot;, &quot;fillColor&quot;: &quot;#1e1149&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;11&quot;: case &quot;100&quot;: case &quot;152&quot;: case &quot;183&quot;: case &quot;247&quot;: case &quot;317&quot;:
#                     return {&quot;color&quot;: &quot;#06051a&quot;, &quot;fillColor&quot;: &quot;#06051a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;66&quot;: case &quot;106&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;145&quot;: case &quot;178&quot;: case &quot;216&quot;:
#                     return {&quot;color&quot;: &quot;#0a0822&quot;, &quot;fillColor&quot;: &quot;#0a0822&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;45&quot;: case &quot;59&quot;: case &quot;68&quot;: case &quot;110&quot;: case &quot;174&quot;: case &quot;179&quot;: case &quot;189&quot;: case &quot;312&quot;:
#                     return {&quot;color&quot;: &quot;#08071e&quot;, &quot;fillColor&quot;: &quot;#08071e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;19&quot;: case &quot;55&quot;: case &quot;73&quot;: case &quot;98&quot;: case &quot;117&quot;: case &quot;236&quot;: case &quot;262&quot;: case &quot;305&quot;:
#                     return {&quot;color&quot;: &quot;#120d31&quot;, &quot;fillColor&quot;: &quot;#120d31&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;70&quot;: case &quot;97&quot;: case &quot;143&quot;: case &quot;181&quot;: case &quot;219&quot;: case &quot;243&quot;:
#                     return {&quot;color&quot;: &quot;#0d0a29&quot;, &quot;fillColor&quot;: &quot;#0d0a29&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#6d1d81&quot;, &quot;fillColor&quot;: &quot;#6d1d81&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;78&quot;: case &quot;91&quot;: case &quot;111&quot;: case &quot;127&quot;: case &quot;129&quot;: case &quot;252&quot;:
#                     return {&quot;color&quot;: &quot;#241253&quot;, &quot;fillColor&quot;: &quot;#241253&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;: case &quot;113&quot;:
